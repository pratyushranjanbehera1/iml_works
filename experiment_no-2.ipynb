# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,5,4,5])
mean_x=np.mean(x)
mean_y=np.mean(y)
print(mean_x,mean_y)

# %%
x=[1,2,3,4,5]
y=[2,4,5,4,5]
plt.plot(x,y)
plt.title("X VS Y")
plt.xlabel("X")
plt.ylabel("Y")
